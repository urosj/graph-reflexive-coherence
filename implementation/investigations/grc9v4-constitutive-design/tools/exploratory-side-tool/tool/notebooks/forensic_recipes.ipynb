# %% [markdown]
# # GRCv4 forensic recipes
#
# This notebook only orchestrates accepted ET-C3 forensic functions. It does not implement scientific or counterfactual logic.

# %%
from grcv4_explorer.forensic import candidate_career, load_forensic_context, reconstruction_path, write_trace
context = load_forensic_context(repo_root, side_tool_root)

# %%
write_trace(output_dir / 'normative-claim.json', reconstruction_path(context, 'D10-CL-N-001'))
write_trace(output_dir / 'candidate-B.json', candidate_career(context, 'V4-B-independent-derived-carrier'))
